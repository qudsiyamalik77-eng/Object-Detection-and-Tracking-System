# %%
# !pip install ultralytics gradio filterpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 17.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 57.5 MB/s eta 0:00:00
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110460 sha256=6feb0391eae6c4c73e2703ee4422178a68ab3cf174dfff2b0ade846d80e61527
#   Stored in directory: /root/.cache/pip/wheels/77/bf/4c/b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built filterpy
# ...

# %%
# Download the SORT implementation script
# !wget https://raw.githubusercontent.com/abewley/sort/master/sort.py
# Out:
# --2026-05-14 15:36:47--  https://raw.githubusercontent.com/abewley/sort/master/sort.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11739 (11K) [text/plain]
# Saving to: ‘sort.py’
#
# sort.py             100%[===================>]  11.46K  --.-KB/s    in 0s
#
# 2026-05-14 15:36:47 (115 MB/s) - ‘sort.py’ saved [11739/11739]

# %%
import cv2
import numpy as np
import gradio as gr
from ultralytics import YOLO
from sort import Sort
import tempfile
import os

# Initialize models
model = YOLO('yolov8n.pt')
tracker = Sort(max_age=20, min_hits=3, iou_threshold=0.3)

def process_video(video_input):
    if video_input is None:
        return None

    cap = cv2.VideoCapture(video_input)
    width, height = int(cap.get(3)), int(cap.get(4))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    temp_out = tempfile.NamedTemporaryFile(suffix='.mp4', delete=False).name
    out = cv2.VideoWriter(temp_out, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret: break

        results = model(frame, stream=True)
        detections = []
        for r in results:
            for box in r.boxes:
                x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                conf = box.conf[0].cpu().numpy()
                if conf > 0.4:
                    detections.append([x1, y1, x2, y2, conf])

        if len(detections) > 0:
            trackers = tracker.update(np.array(detections))
            for trk in trackers:
                x1, y1, x2, y2, track_id = trk.astype(int)
                # Neon Green and Blue color for boxes
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 191, 0), 2)
                cv2.putText(frame, f"Object ID: {track_id}", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 191, 0), 2)
        out.write(frame)

    cap.release()
    out.release()

    final_output = "styled_tracker.mp4"
    os.system(f"ffmpeg -y -i {temp_out} -vcodec libx264 {final_output}")
    return final_output

# --- Custom Styling & UI ---
with gr.Blocks(theme=gr.themes.Default(primary_hue="cyan", secondary_hue="blue")) as demo:

    # Header Section
    gr.HTML("""
        <div style="background-color: #1e293b; padding: 20px; border-radius: 15px; margin-bottom: 25px">
            <h1 style="text-align: center; color: #38bdf8; font-family: 'Arial'; margin: 0;">🎯 Object Detection and Tracking</h1>
            <p style="text-align: center; color: #94a3b8; font-size: 16px;">AI-Powered Real-Time Video Analysis & Object ID Assignment</p>
        </div>
    """)

    with gr.Row():
        # Input Section
        with gr.Column(scale=1):
            gr.Markdown("### 📥 Step 1: Upload Video")
            video_in = gr.Video(label="Source File")
            submit_btn = gr.Button("🔥 START DETECTION", variant="primary", size="lg")

        # Output Section
        with gr.Column(scale=1):
            gr.Markdown("### 📤 Step 2: Tracked Results")
            video_out = gr.Video(label="AI Processed Video", interactive=False)

            with gr.Accordion("More Options & Download", open=True):
                download_btn = gr.File(label="Click to Save Video Locally")

    # Footer Information
    gr.HTML("<p style='text-align: center; color: #64748b; margin-top: 20px;'>Internship Task - Powered by YOLOv8 & SORT Tracker</p>")

    # Logic Connection
    submit_btn.click(
        fn=process_video,
        inputs=video_in,
        outputs=video_out
    ).then(
        fn=lambda x: x,
        inputs=video_out,
        outputs=download_btn
    )

demo.launch(share=True)
# Out:
# /tmp/ipykernel_4332/1654786613.py:55: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=gr.themes.Default(primary_hue="cyan", secondary_hue="blue")) as demo:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://98689fab9482e9c35e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://98689fab9482e9c35e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
